# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

from ipynb.fs.full.Cert_Aux_Functions2 import *

# Importa a biblioteca pandas 
import pandas as pd

# Importa datetime e timedelta para verificar se há gaps de tempo nos datasets preparados
from datetime import datetime, timedelta

# Importa a biblioteca os
import os
from pathlib import Path

## Bibliotecas sklearn
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector as selector
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler, FunctionTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.impute import SimpleImputer

# Using Kernel PCA
from sklearn.decomposition import PCA, KernelPCA

# Using Gaussian Mixtures
from sklearn.mixture import GaussianMixture

# One Class SVM
# https://scikit-learn.org/stable/auto_examples/svm/plot_oneclass.html
from sklearn import svm
from sklearn import linear_model

#Para as figuras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#Importa bibliotecas Numpy
import numpy as np

# Importa as bibliotecas para os cálculos do desvio padrao
from scipy.stats import norm
from scipy.stats import chi2
import statistics

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

from keras import optimizers, Sequential
from keras.models import Model
#from keras.utils import plot_model
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed
from keras.callbacks import ModelCheckpoint, TensorBoard

from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

import warnings
warnings.filterwarnings("ignore")

# %%
# Logon + HTTP + USB + Device
df_lhud_1hora = pd.read_pickle("df_lhud_1hora_file.pkl")
df_lhud_1hora.sort_values('date', ascending=True, inplace = True)
df_lhud_1hora.reset_index(inplace = True, drop=True)

## Separa 4 primeiros meses de dados
df_lhud_1hora4m = df_lhud_1hora[(df_lhud_1hora['date'] <= '2010-05-02')]

train_index = df_lhud_1hora4m.index[-1]
test_index = df_lhud_1hora[(df_lhud_1hora['date'] <= '2010-09-02')].index[-1]


## Conjunto de teste
df_lhud_1hora_test = df_lhud_1hora.iloc[train_index:test_index]

### Transformações

#Nomes das features numericas de acordo com o dataset
lhud_numeric_features = ['logon', 'logoff','down','up','vis',
                     'conn','disc','trm','frm','open',
                     'write','copy','delete']

#Nomes das features categoricas - comum a todos os datasets

#numeric_transformer = StandardScaler() ## removing the mean and scaling to unit variance.
numeric_transformer = MinMaxScaler() ## Varia de 0 a 1
#numeric_transformer = SimpleImputer()

hour_categories = np.arange(0, 24)
dow_categories  = np.arange(0, 7)
user_categories = df_lhud_1hora4m.user.unique()

#categorical_features = ['user','hour', 'dow']
categorical_features = ['hour', 'dow']
categorical_transformer = OneHotEncoder(
#    categories = [user_categories, hour_categories, dow_categories]
    categories = [hour_categories, dow_categories]
)

user_feature = ['user']
user_transformer = OrdinalEncoder(categories = [user_categories])
user_transformer_wd = OneHotEncoder(categories = [user_categories])

lhud_preprocessor = ColumnTransformer(
    transformers=[
        ('lhud_num', numeric_transformer, lhud_numeric_features),
        ('lhud_cat', categorical_transformer, categorical_features),
        ('lhud_user', user_transformer, user_feature),
    ])

lhud_preprocessor_deep = ColumnTransformer(
    transformers=[
        ('lhud_num', numeric_transformer, lhud_numeric_features),
    ])

lhud_preprocessor_wide = ColumnTransformer(
    transformers=[
        ('lhud_cat', categorical_transformer, categorical_features),
        ('lhud_user_wd', user_transformer_wd, user_feature),
    ])

#Transformaçoes simples, com dados todos juntos
columns = lhud_numeric_features + categorical_features + user_feature
trans_lhud_4m    = lhud_preprocessor.fit_transform(df_lhud_1hora4m[columns])
trans_lhud_test  = lhud_preprocessor.transform(df_lhud_1hora_test[columns])
trans_lhud       = lhud_preprocessor.transform(df_lhud_1hora[columns])

#Transformaçoes deep
columns_deep = lhud_numeric_features# + categorical_features + user_feature
trans_lhud_4m_deep    = lhud_preprocessor_deep.fit_transform(df_lhud_1hora4m[columns_deep])
trans_lhud_test_deep       = lhud_preprocessor_deep.transform(df_lhud_1hora_test[columns_deep])

#Transformaçoes wide
columns_wide = categorical_features + user_feature
trans_lhud_4m_wide    = lhud_preprocessor_wide.fit_transform(df_lhud_1hora4m[columns_wide])
trans_lhud_test_wide       = lhud_preprocessor_wide.transform(df_lhud_1hora_test[columns_wide])

# %%
### Carrega do arquivos e dados do insider1

### Carrega do arquivo
acm2278_test = pd.read_pickle("acm2278_test.pkl")

### Carrega do arquivo
acm2278_test_full = pd.read_pickle("acm2278_test_full.pkl")

user = 'ACM2278'


### Carrega Labels preditos do Snorkel *** Ajustados
labels_pd = pd.read_hdf("labels_pd.hdf",'df')
labels_pd['anom'] = np.where((labels_pd[0]== 1),-1,1)
labels_pd[labels_pd['anom'] == -1].shape, labels_pd[labels_pd['anom'] == 1].shape

### Carrega Labels preditos do Snorkel *** General
labels_g_pd = pd.read_hdf("labels_g_pd.hdf",'df')
labels_g_pd['anom'] = np.where((labels_g_pd[0]== 1),-1,1)
labels_g_pd[labels_g_pd['anom'] == -1].shape, labels_g_pd[labels_g_pd['anom'] == 1].shape
# Out:
# ((6229, 2), (3272702, 2))

# %%
#del ds_deep_test
#del ds_wide_test
#del ds_test

#del ds_deep_train
#del ds_wide_train
#del ds_train

n_steps = 1
wind = n_steps
batch_size = 1024

ds_deep_train = tf.data.Dataset.from_tensor_slices(trans_lhud_4m_deep)
ds_wide_train = tf.data.Dataset.from_tensor_slices(convert_sparse_matrix_to_sparse_tensor(trans_lhud_4m_wide))

ds_deep_train = ds_deep_train.window(wind, shift=n_steps, drop_remainder=True
                                    ).flat_map(lambda window: window.batch(wind)
                                    )

ds_wide_train = ds_wide_train.window(wind, shift=n_steps, drop_remainder=True
                                    ).flat_map(lambda window: window.batch(wind)
                                    )

ds_train = tf.data.Dataset.zip(({"deep_input": ds_deep_train, "wide_input": ds_wide_train}, ds_deep_train))

ds_train = ds_train.batch(batch_size).cache().prefetch(1)


ds_deep_test = tf.data.Dataset.from_tensor_slices(trans_lhud_test_deep)
ds_wide_test = tf.data.Dataset.from_tensor_slices(convert_sparse_matrix_to_sparse_tensor(trans_lhud_test_wide))

ds_deep_test = ds_deep_test.window(wind, shift=n_steps, drop_remainder=True
                                    ).flat_map(lambda window: window.batch(wind)
                                    )

ds_wide_test = ds_wide_test.window(wind, shift=n_steps, drop_remainder=True
                                    ).flat_map(lambda window: window.batch(wind)
                                    )


ds_test = tf.data.Dataset.zip(({"deep_input": ds_deep_test, "wide_input": ds_wide_test}, ds_deep_test))

ds_test = ds_test.batch(batch_size).cache().prefetch(1)

ds_train.element_spec, ds_test.element_spec
# Out:
# (({'deep_input': TensorSpec(shape=(None, None, 13), dtype=tf.float64, name=None),
#    'wide_input': SparseTensorSpec(TensorShape([None, None, 4031]), tf.float64)},
#   TensorSpec(shape=(None, None, 13), dtype=tf.float64, name=None)),
#  ({'deep_input': TensorSpec(shape=(None, None, 13), dtype=tf.float64, name=None),
#    'wide_input': SparseTensorSpec(TensorShape([None, None, 4031]), tf.float64)},
#   TensorSpec(shape=(None, None, 13), dtype=tf.float64, name=None)))

# %%
##otimizado
def objective(space):

    input_feat = keras.layers.Input(shape=[None, 13], name="deep_input")
    input_time_user = keras.layers.Input(shape=[None, 4031], name="wide_input")
   
    conv1d_ae = keras.models.Sequential([
    keras.layers.Conv1D(filters=space['filters'], kernel_size=space['kernel_s'], strides=1, padding="same",
                        activation="selu", input_shape=[None, 13]),
    keras.layers.LSTM(space['first'], activation='tanh', return_sequences=True),
    keras.layers.LSTM(space['intermediate'], activation='tanh', return_sequences=False),
    keras.layers.RepeatVector(wind),
    keras.layers.LSTM(space['intermediate'], activation='tanh', return_sequences=True),
    keras.layers.LSTM(space['first'], activation='tanh', return_sequences=True),
    ])

    conv1d_ae = conv1d_ae(input_feat)

    concat = keras.layers.concatenate([input_time_user, conv1d_ae])

    #last = keras.models.Sequential()
    #last.add(keras.layers.Dense(space['last'], kernel_initializer=space['kernel_init']))
    #last.add(keras.layers.BatchNormalization())
    #last.add(keras.layers.Activation("elu"))
    #last.add(keras.layers.Dropout(space['dropout']))
    
    last = keras.models.Sequential()
    last.add(keras.layers.Dense(space['last'], 
                                kernel_initializer=space['kernel_init']))    
    if space['last_batch_layer']:
        last.add(keras.layers.BatchNormalization())
    last.add(keras.layers.Activation("elu"))
    if space['l1reg_layer']:
        last.add(keras.layers.ActivityRegularization(space['l1_reg']))
    if space['dropout_layer']:
        last.add(keras.layers.Dropout(space['dropout']))
    last = last(concat)    
    
    output = keras.layers.Dense(13, name="output")(last)

    model = keras.models.Model(inputs=[input_feat, input_time_user], outputs=[output])

    model.compile(loss=space['loss_ob'], optimizer=space['optimizer'], metrics=space['metrics'])

    history = model.fit(ds_train, epochs=space['epochs'], verbose=0)
    
    y_pred = model.predict(ds_test)
    
    #anomalyScores, den_thres = anomScores_Snorkel(
    anomalyScores, den_thres = dnn_tf_anomScores(
    y_pred, trans_lhud_test_deep, df_lhud_1hora_test, 99.0)
    
    a,p,r,f,cm,auc_sc = benchmark_snorkel(labels_g_pd,anomalyScores)
    
    global index
    scores_df.loc[index,:]=np.array([index,space,a,p,r,f,auc_sc,np.reshape(cm,(4))],dtype=object)
    
    index=index+1
    
    print(space,r)
    
    return {'loss': -r, 'status': STATUS_OK, 'space': space,
            'model': model, 'f1_score': f,'auc_sc': auc_sc,
           'precision': p, 'recall': r, 'c_matrix': cm}

space ={'filters': hp.choice('filters', [10, 11, 12, 13]),
        'kernel_s': hp.choice('kernel_s', [1, 2, 3, 4, 5, 6]),
        'first': hp.choice('first', np.arange(7,14,1)),
        'intermediate': hp.choice('intermediate', np.arange(4, 11, 1)),
        'last' : hp.choice('last', np.arange(100,500,25)),
        'kernel_init' : hp.choice('kernel_init', ["he_normal"]),
        'activ' : hp.choice('activ', ["elu"]),
        'loss_ob' : hp.choice('loss_ob', ["mae"]), #"Huber"
        'optimizer' : hp.choice('optimizer', ["nadam"]),
        'metrics' : hp.choice('metrics', ["mean_absolute_error","mean_squared_error"]),
        'epochs' : hp.choice('epochs', [10]),
        'l1_reg' : hp.choice('l1_reg', [0.00001, 0.00005, 0.0001,0.0005,0.001,0.005,0.01]),
        'dropout' : hp.choice('dropout', [0.0, 0.05, 0.1, 0.15, 0.2]),
        'last_batch_layer': hp.choice('last_batch_layer', [True, False]),
        'l1reg_layer': hp.choice('l1reg_layer', [True, False]),
        'dropout_layer':hp.choice('dropout_layer', [True, False])
    }

# %%
#Rodada com Recall ??

#comentadas pra manter os  resultados anteriores no pd.dataframe
#scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
#index=0
#scores_df.info()

scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
index=0

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.25317065339540856
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.454326537164874
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.25028094397174505
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 175, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.229731899181249
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5728046235350779
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2706694493498154
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.23807994862738802
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.27307754053620165
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5705570717611174
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2583079145930326
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5988120083480495
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3199550489645208
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 175, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2478728527853588
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.27628832878471665
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2907368759030342
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 300, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5368437951517098
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36602986033071117
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3136940118799165
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2520468775084283
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5683095199871568
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 325, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5644565740889388
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5370043345641355
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.22347086209664474
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 150, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5365227163268582
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2812650505699149
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 400, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2621608604912506
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 425, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.29346604591427194
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2910579547278857
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6156686466527532
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2478728527853588
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2472306951356558
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.23695617274040778
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.618397816663991
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.27243538288649866
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5928720500882967
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3634612297318992
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6057152030823567
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.305667041258629
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.24321720982501205
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6166318831273078
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.29057633649060843
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.25301011398298284
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2417723551131803
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.456253010113983
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 175, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6084443730935944
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4467811847808637
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.29731899181248994
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5991330871729009
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.25301011398298284
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4597848771873495
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.38898699630759354
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.29908492534917325
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 150, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.27693048643441964
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.23824048803981376
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2742013164231819
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2522074169208541
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 175, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2552576657569433
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2876866270669449
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.30277733183496547
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 150, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3348852143201156
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3348852143201156
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6204848290255258
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.24129073687590302
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.23502969979129876
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6103708460427035
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2525284957457056
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5626906405522556
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5313854551292342
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2640873334403596
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4535238401027452
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.231658372130358
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2446620645368438
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5734467811847809
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2660138063894686
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.22250762562209023
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.620966447262803
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 13, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.39894043987799005
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2576657569433296
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5989725477604751
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.28608123294268745
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2504414833841708
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2611976240166961
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.25333119280783434
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.42157649703002087
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 425, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.24514368277412105
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 9, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2873655482420934
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2595922298924386
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.20677476320436666
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6166318831273078
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 150, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.40022475517739603
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4207737999678921
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.41210467169690157
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5991330871729009
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2648900305024884
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.22491571680847647
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5872531706533954
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5716808476480976
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.24418044629956653
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2754856317225879
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 100, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.30550650184620326
# 100%|███████████████████████████████████████████| 100/100 [9:44:45<00:00, 350.86s/trial, best loss: -0.620966447262803]

# %%
#scores_df.sort_values(['ROC-AUC'], ascending=[False])#.loc[:,('Params','Recall','ROC-AUC')]
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#    Model                                             Params  Accuracy  \
# 94    94  {'activ': 'elu', 'dropout': 0.2, 'dropout_laye...  0.990467
# 69    69  {'activ': 'elu', 'dropout': 0.2, 'dropout_laye...  0.990456
# 7      7  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.990434
# 87    87  {'activ': 'elu', 'dropout': 0.1, 'dropout_laye...  0.990411
# 84    84  {'activ': 'elu', 'dropout': 0.1, 'dropout_laye...  0.990394
# ..   ...                                                ...       ...
# 22    22  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.988962
# 31    31  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.988932
# 74    74  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.988931
# 36    36  {'activ': 'elu', 'dropout': 0.0, 'dropout_laye...  0.988916
# 77    77  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.988906
#
#    Precision    Recall  F1-Score   ROC-AUC                            CM
# 94  0.118329  0.622893  0.198877  0.900966  [3243792, 28910, 2349, 3880]
# 69   0.11781  0.620164  0.198006  0.910598  [3243775, 28927, 2366, 3863]
# 7   0.116682  0.614224   0.19611  0.930548  [3243738, 28964, 2403, 3826]
# 87  0.115554  0.608284  0.194213    0.9292  [3243701, 29001, 2440, 3789]
# 84  0.114669  0.603628  0.192727  0.926184  [3243672, 29030, 2469, 3760]
# ..       ...       ...       ...       ...                           ...
# 22  0.043092  0.226842  0.072426  0.810787  [3241325, 31377, 4816, 1413]
# 31  0.041598  0.218976  0.069915  0.869472  [3241276, 31426, 4865, 1364]
# 74  0.041537  0.218655  0.069812  0.806844  [3241274, 31428, 4867, 1362]
# 36  0.040775  0.214641  0.068531  0.863259  [3241249, 31453, 4892, 1337]
# 77  0.040287  0.212073  0.067711  0.871004  [3241233, 31469, 4908, 1321]
#
# [100 rows x 8 columns]

# %%
#Rodada com Recall 68,64%

#comentadas pra manter os  resultados anteriores no pd.dataframe
#scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
#index=0
#scores_df.info()

scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
index=0

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5827580671054744
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3613742173703644
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5861293947664151
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5084283191523519
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5829186065179002
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5439075292984428
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.680205490447905
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.569433295874137
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.33857762080590786
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3533472467490769
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4212554182051694
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5578744581794831
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36908010916680045
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.555947985230374
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5442286081232943
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.545031305185423
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3520629314496709
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5305827580671054
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.523840102745224
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5925509712634451
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.684058436346123
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3449991973029379
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6378230855675068
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6855032910579547
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3581634291218494
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3536683255739284
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3377749237437791
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36281907208219616
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35928720500882966
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6005779418847327
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4707015572323005
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4734307272435383
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36281907208219616
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.38208380157328625
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.33504575373254136
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.45801894365066625
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35270508909937387
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34965484026328464
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6822925028094398
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.43827259592229895
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4840263284636378
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.39589019104190076
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35158131321239366
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6826135816342912
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5760154117835928
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5301011398298282
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36619039974313694
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5010435061807674
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4668486113340825
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5284957457055707
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.38914753572001926
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.6195215925509713
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3718092791780382
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35639749558516615
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5002408091186387
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.39508749397977205
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.523840102745224
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35639749558516615
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5665435864504736
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3575212714721464
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3552737196981859
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5073045432653717
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36522716326858246
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3504575373254134
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36201637502006745
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3799967892117515
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.42237919409214963
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3666720179804142
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35912666559640394
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3615347567827902
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3612136779579387
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6728206774763205
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36201637502006745
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6864665275325093
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34628351260234386
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.38657890512120724
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6818108845721624
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6797238722106277
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.49510354792101463
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5206293144967089
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3685984909295232
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.35543425911061166
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6375020067426553
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.540536201637502
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6822925028094398
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6776368598490929
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.37855193449991975
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5864504735912667
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3568791138224434
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.35880558677155244
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.61390271311607
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.39219778455610854
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5240006421576497
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3478889067266014
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3477283673141756
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3510996949751164
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.46813292663348854
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34628351260234386
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4069674104992776
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3695617274040777
# 100%|██████████████████████████████████████████| 100/100 [8:32:21<00:00, 307.41s/trial, best loss: -0.6864665275325093]

# %%
#scores_df.sort_values(['ROC-AUC'], ascending=[False])#.loc[:,('Params','Recall','ROC-AUC')]
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#    Model                                             Params  Accuracy  \
# 73    73  {'activ': 'elu', 'epochs': 10, 'filters': 10, ...  0.980708
# 23    23  {'activ': 'elu', 'epochs': 10, 'filters': 10, ...  0.980705
# 20    20  {'activ': 'elu', 'epochs': 10, 'filters': 10, ...  0.980699
# 43    43  {'activ': 'elu', 'epochs': 10, 'filters': 11, ...  0.980694
# 38    38  {'activ': 'elu', 'epochs': 10, 'filters': 10, ...  0.980692
# ..   ...                                                ...       ...
# 97    97  {'activ': 'elu', 'epochs': 10, 'filters': 13, ...  0.979416
# 21    21  {'activ': 'elu', 'epochs': 10, 'filters': 10, ...  0.979411
# 8      8  {'activ': 'elu', 'epochs': 10, 'filters': 13, ...  0.979387
# 26    26  {'activ': 'elu', 'epochs': 10, 'filters': 12, ...  0.979384
# 34    34  {'activ': 'elu', 'epochs': 10, 'filters': 12, ...  0.979373
#
#    Precision    Recall  F1-Score   ROC-AUC                            CM
# 73  0.065204  0.686467  0.119095  0.939151  [3211399, 61303, 1953, 4276]
# 23  0.065112  0.685503  0.118928   0.92963  [3211393, 61309, 1959, 4270]
# 20  0.064975  0.684058  0.118678  0.937634  [3211384, 61318, 1968, 4261]
# 43  0.064838  0.682614  0.118427  0.935471  [3211375, 61327, 1977, 4252]
# 38  0.064807  0.682293  0.118371  0.937759  [3211373, 61329, 1979, 4250]
# ..       ...       ...       ...       ...                           ...
# 97  0.032892  0.346284  0.060077   0.89085  [3209280, 63422, 4072, 2157]
# 21   0.03277  0.344999  0.059854  0.883029  [3209272, 63430, 4080, 2149]
# 8    0.03216  0.338578   0.05874  0.892773  [3209232, 63470, 4120, 2109]
# 26  0.032083  0.337775  0.058601  0.873759  [3209227, 63475, 4125, 2104]
# 34  0.031824  0.335046  0.058127  0.905987  [3209210, 63492, 4142, 2087]
#
# [100 rows x 8 columns]

# %%
#Rodada com Recall 68,61%

#comentadas pra manter os  resultados anteriores no pd.dataframe
#scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
#index=0
#scores_df.info()

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 350, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34997591908813613
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 250, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.301814095360411
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 325, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.38577620805907853
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 250, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.04430887782950715
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.40921496227323806
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 100, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2547760475196661
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 13, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 175, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2754856317225879
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 7, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6376625461550811
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.68341627869642
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.36522716326858246
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6826135816342912
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5538609728688393
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5707176111735431
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 9, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 175, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2647294910900626
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 325, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.29731899181248994
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 150, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.34210948787927437
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 450, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2819072082196179
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6660780221544389
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6822925028094398
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 175, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.304382725959223
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3562369561727404
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3779097768502167
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34997591908813613
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3618558356076417
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35928720500882966
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.6288328784716648
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 13, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36233745384491894
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5413388986996308
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6818108845721624
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5984909295231979
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3604109808958099
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3613742173703644
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5362016375020068
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3478889067266014
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35286562851179964
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5151709744742334
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6830951998715684
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.307593514207738
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.675068229250281
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.4902873655482421
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 425, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.31064376304382724
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.680205490447905
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.37277251565259273
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.049125060202279656
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2592711510675871
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 350, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.28656285117996466
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 300, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5344357039653235
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 225, 'loss_ob': 'mse', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.27965965644565743
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3607320597206614
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3355273719698186
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3674747150425429
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5606036281907208
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 13, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6797238722106277
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 175, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3546315620484829
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.26424787285278534
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 350, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35703965323486914
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.5614063252528496
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 400, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2774121046716969
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3507786161502649
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.35222347086209665
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 13, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5267298121688875
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 125, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.46251404719858724
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 300, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3572001926472949
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3520629314496709
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'adam'}
# 0.6025044148338418
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4165997752448226
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3612136779579387
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 150, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.48563172258789533
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3539894043987799
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6832557392839942
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6822925028094398
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4509552095039332
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3653877026810082
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36522716326858246
# {'activ': 'elu', 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34997591908813613
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'last': 250, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3618558356076417
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6861454487076577
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.682774121046717
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 450, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.32332637662546154
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 350, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3507786161502649
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5169369080109166
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4334564135495264
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5248033392197785
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3517418526248194
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 125, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.42205811526729814
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 400, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5203082356718575
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 275, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4138706052335848
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 425, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36490608444373096
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 9, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 300, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.27965965644565743
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 225, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.6137421737036443
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3779097768502167
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 375, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.40247230695135655
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 250, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2690640552255579
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 2, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.36330069031947343
# {'activ': 'elu', 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'last': 175, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5201476962594317
# {'activ': 'elu', 'epochs': 10, 'filters': 9, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 100, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6822925028094398
# {'activ': 'elu', 'epochs': 10, 'filters': 13, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 200, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3613742173703644
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'last': 450, 'loss_ob': 'mse', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.28640231176753894
# {'activ': 'elu', 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'last': 475, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'adam'}
# 0.5403756622250763
# {'activ': 'elu', 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'last': 325, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.37887301332477125
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [9:22:07<00:00, 337.28s/trial, best loss: -0.6861454487076577]

# %%
#scores_df.sort_values(['ROC-AUC'], ascending=[False])#.loc[:,('Params','Recall','ROC-AUC')]
scores_df[100:].sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#     Model                                             Params  Accuracy  \
# 176   176  {'activ': 'elu', 'epochs': 10, 'filters': 12, ...  0.980707
# 108   108  {'activ': 'elu', 'epochs': 10, 'filters': 8, '...  0.980697
# 169   169  {'activ': 'elu', 'epochs': 10, 'filters': 12, ...  0.980696
# 136   136  {'activ': 'elu', 'epochs': 10, 'filters': 8, '...  0.980696
# 177   177  {'activ': 'elu', 'epochs': 10, 'filters': 12, ...  0.980694
# ..    ...                                                ...       ...
# 154   154  {'activ': 'elu', 'epochs': 10, 'filters': 13, ...  0.979104
# 144   144  {'activ': 'elu', 'epochs': 10, 'filters': 13, ...  0.979085
# 105   105  {'activ': 'elu', 'epochs': 10, 'filters': 8, '...  0.979068
# 143   143  {'activ': 'elu', 'epochs': 10, 'filters': 8, '...  0.978287
# 103   103  {'activ': 'elu', 'epochs': 10, 'filters': 9, '...  0.978269
#
#     Precision    Recall  F1-Score   ROC-AUC                            CM
# 176  0.065173  0.686145   0.11904  0.926301  [3211397, 61305, 1955, 4274]
# 108  0.064914  0.683416  0.118566  0.934261  [3211380, 61322, 1972, 4257]
# 169  0.064899  0.683256  0.118538  0.928241  [3211379, 61323, 1973, 4256]
# 136  0.064884  0.683095   0.11851  0.924981  [3211378, 61324, 1974, 4255]
# 177  0.064853  0.682774  0.118455   0.93863  [3211376, 61326, 1976, 4253]
# ..        ...       ...       ...       ...                           ...
# 154  0.025099  0.264248  0.045844  0.776766  [3208769, 63933, 4583, 1646]
# 144  0.024627  0.259271  0.044981  0.817335  [3208738, 63964, 4614, 1615]
# 105    0.0242  0.254776  0.044201  0.767131  [3208710, 63992, 4642, 1587]
# 143  0.004666  0.049125  0.008523  0.678384   [3207429, 65273, 5923, 306]
# 103  0.004209  0.044309  0.007687  0.474608   [3207399, 65303, 5953, 276]
#
# [100 rows x 8 columns]

# %%
#Rodada com Recall 68,87%

scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
index=0
#scores_df.info()

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3116069995183818
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 300, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.27339861936105314
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5703965323486916
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4008669128270991
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3384170813934821
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5198266174345801
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 425, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.28961310001605395
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2385615668646653
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 275, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.44469417241932896
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 7, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2725959222989244
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.40841226521110935
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2677797399261519
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3742173703644245
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5951196018622572
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.30309841065981696
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5493658693209182
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': True, 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2709905281746669
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4360250441483384
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 13, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.37919409214962274
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 9, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.0005, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2512441804462996
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36811687269224597
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 12, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5739283994220581
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5941563653877027
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 150, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5938352865628512
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5941563653877027
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 12, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 375, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5931931289131481
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 9, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.005, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5943169048001284
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6423181891154278
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6439235832396853
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4769625943169048
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6418365708781506
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 250, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6419971102905764
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6394284796917643
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 300, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5824369882806228
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3536683255739284
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.5962433777492374
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 8, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6129394766415155
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 12, 'first': 13, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.43907529298442766
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': True, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 275, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.41932894525606035
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 12, 'first': 8, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 1e-05, 'l1reg_layer': True, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.39765612457858407
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 13, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 175, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3910740086691283
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3475678279017499
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 0.0005, 'l1reg_layer': True, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6431208861775566
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': True, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 5, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': True, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.43490126826135816
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6810081875100337
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 150, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36940118799165195
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.29924546476159897
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': True, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.469738320757746
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.321078824851501
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.536041098089581
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': True, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2547760475196661
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.371327660940761
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4753572001926473
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.01, 'l1reg_layer': True, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3467651308396211
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6845400545834002
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3506180767378391
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6602986033071119
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3710065821159095
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.37229089741531546
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.38304703804784074
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3446781184780864
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 10, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.36314015090704765
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 8, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.35607641676031465
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3416278696419971
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 150, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3448386578905121
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6794027933857762
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6810081875100337
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6792422539733505
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.5195055386097287
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4039171616631883
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6362176914432494
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 9, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6806871086851822
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 12, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 475, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3397013966928881
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34050409375501683
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6818108845721624
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.4108203563974956
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 7, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3510996949751164
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3616952961952159
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.2660138063894686
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 225, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.35543425911061166
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.0001, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3580028897094237
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 9, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.34933376143843314
# {'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 5e-05, 'l1reg_layer': True, 'last': 100, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2809439717450634
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.6887140793064698
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 325, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.4458179483063092
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.35350778616150264
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.48434740728848935
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.27307754053620165
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 10, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3750200674265532
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 450, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.42864023117675387
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 7, 'intermediate': 9, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 425, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.37004334564135494
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 8, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 150, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.561727404077701
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 250, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.3536683255739284
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 9, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 300, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.3613742173703644
# {'activ': 'elu', 'dropout': 0.0, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 10, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 375, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.42253973350457535
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 11, 'first': 10, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 4, 'l1_reg': 0.01, 'l1reg_layer': False, 'last': 350, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.6813292663348852
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': True, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 6, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'Huber', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.2854390752929844
# {'activ': 'elu', 'dropout': 0.15, 'dropout_layer': False, 'epochs': 10, 'filters': 8, 'first': 7, 'intermediate': 5, 'kernel_init': 'he_normal', 'kernel_s': 2, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 200, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.37293305506501845
# {'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 12, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 3, 'l1_reg': 5e-05, 'l1reg_layer': False, 'last': 225, 'last_batch_layer': True, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
# 0.29571359768823247
# {'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 9, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 0.005, 'l1reg_layer': False, 'last': 275, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
# 0.635093915556269
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [9:48:43<00:00, 353.24s/trial, best loss: -0.6887140793064698]

# %%
#scores_df.sort_values(['ROC-AUC'], ascending=[False])#.loc[:,('Params','Recall','ROC-AUC')]
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#    Model                                             Params  Accuracy  \
# 83    83  {'activ': 'elu', 'dropout': 0.05, 'dropout_lay...  0.980717
# 54    54  {'activ': 'elu', 'dropout': 0.1, 'dropout_laye...  0.980701
# 74    74  {'activ': 'elu', 'dropout': 0.2, 'dropout_laye...  0.980691
# 95    95  {'activ': 'elu', 'dropout': 0.1, 'dropout_laye...  0.980689
# 66    66  {'activ': 'elu', 'dropout': 0.2, 'dropout_laye...  0.980688
# ..   ...                                                ...       ...
# 11    11  {'activ': 'elu', 'dropout': 0.0, 'dropout_laye...  0.979118
# 78    78  {'activ': 'elu', 'dropout': 0.15, 'dropout_lay...  0.979111
# 50    50  {'activ': 'elu', 'dropout': 0.2, 'dropout_laye...  0.979068
# 19    19  {'activ': 'elu', 'dropout': 0.1, 'dropout_laye...  0.979055
# 7      7  {'activ': 'elu', 'dropout': 0.0, 'dropout_laye...  0.979007
#
#    Precision    Recall  F1-Score   ROC-AUC                            CM
# 83  0.065417  0.688714  0.119485  0.940494  [3211413, 61289, 1939, 4290]
# 54  0.065021   0.68454  0.118761  0.934148  [3211387, 61315, 1965, 4264]
# 74  0.064762  0.681811  0.118288  0.935358  [3211370, 61332, 1982, 4247]
# 95  0.064716  0.681329  0.118204  0.926758  [3211367, 61335, 1985, 4244]
# 66  0.064685  0.681008  0.118148  0.929436  [3211365, 61337, 1987, 4242]
# ..       ...       ...       ...       ...                           ...
# 11  0.025435   0.26778  0.046457  0.735527  [3208791, 63911, 4561, 1668]
# 78  0.025267  0.266014  0.046151  0.859202  [3208780, 63922, 4572, 1657]
# 50    0.0242  0.254776  0.044201  0.623463  [3208710, 63992, 4642, 1587]
# 19  0.023864  0.251244  0.043588  0.798334  [3208688, 64014, 4664, 1565]
# 7    0.02266  0.238562  0.041388  0.729033  [3208609, 64093, 4743, 1486]
#
# [100 rows x 8 columns]

# %%
#83	83	{'activ': 'elu', 'dropout': 0.05, 'dropout_lay...	0.980717	0.065417	0.688714	0.119485	0.940494	[3211413, 61289, 1939, 4290]
#{'activ': 'elu', 'dropout': 0.05, 'dropout_layer': False, 'epochs': 10, 'filters': 7, 'first': 11, 'intermediate': 7, 'kernel_init': 'he_normal', 'kernel_s': 1, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 125, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
#.6887140793064698 
model = trials.results[83]['model']
model.save('best_WiDee_Conv_LSTM_v4.h5')

# %%
#54	54	{'activ': 'elu', 'dropout': 0.1, 'dropout_laye...	0.980701	0.065021	0.68454	0.118761	0.934148	[3211387, 61315, 1965, 4264]
#{'activ': 'elu', 'dropout': 0.1, 'dropout_layer': False, 'epochs': 10, 'filters': 13, 'first': 8, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 0.001, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'optimizer': 'nadam'}
#0.6845400545834002
model = trials.results[54]['model']
model.save('best_WiDee_Conv_LSTM_v5.h5')

# %%
#74	74	{'activ': 'elu', 'dropout': 0.2, 'dropout_laye...	0.980691	0.064762	0.681811	0.118288	0.935358	[3211370, 61332, 1982, 4247]
#{'activ': 'elu', 'dropout': 0.2, 'dropout_layer': False, 'epochs': 10, 'filters': 10, 'first': 11, 'intermediate': 4, 'kernel_init': 'he_normal', 'kernel_s': 6, 'l1_reg': 1e-05, 'l1reg_layer': False, 'last': 400, 'last_batch_layer': False, 'loss_ob': 'mae', 'metrics': 'mean_absolute_error', 'optimizer': 'nadam'}
#0.6818108845721624 
model = trials.results[74]['model']
model.save('best_WiDee_Conv_LSTM_v6.h5')
