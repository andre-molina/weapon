# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

from ipynb.fs.full.Cert_Aux_Functions2 import *

# Importa a biblioteca pandas 
import pandas as pd

# Importa datetime e timedelta para verificar se há gaps de tempo nos datasets preparados
from datetime import datetime, timedelta

# Importa a biblioteca os
import os
from pathlib import Path

## Bibliotecas sklearn
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_selector as selector
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, LabelEncoder
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler, FunctionTransformer
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.impute import SimpleImputer

# Using Kernel PCA
from sklearn.decomposition import PCA, KernelPCA

# Using Gaussian Mixtures
from sklearn.mixture import GaussianMixture

# One Class SVM
# https://scikit-learn.org/stable/auto_examples/svm/plot_oneclass.html
from sklearn import svm
from sklearn import linear_model

#Para as figuras
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

#Importa bibliotecas Numpy
import numpy as np

# Importa as bibliotecas para os cálculos do desvio padrao
from scipy.stats import norm
from scipy.stats import chi2
import statistics

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

from keras import optimizers, Sequential
from keras.models import Model
#from keras.utils import plot_model
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed
from keras.callbacks import ModelCheckpoint, TensorBoard

from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

# %%
# Logon + HTTP + USB + Device
df_lhud_1hora = pd.read_pickle("df_lhud_1hora_file.pkl")
df_lhud_1hora.sort_values('date', ascending=True, inplace = True)
df_lhud_1hora.reset_index(inplace = True, drop=True)

## Separa 4 primeiros meses de dados
df_lhud_1hora4m = df_lhud_1hora[(df_lhud_1hora['date'] <= '2010-05-02')]

train_index = df_lhud_1hora4m.index[-1]
test_index = df_lhud_1hora[(df_lhud_1hora['date'] <= '2010-09-02')].index[-1]


## Conjunto de teste
df_lhud_1hora_test = df_lhud_1hora.iloc[train_index:test_index]

### Transformações

#Nomes das features numericas de acordo com o dataset
lhud_numeric_features = ['logon', 'logoff','down','up','vis',
                     'conn','disc','trm','frm','open',
                     'write','copy','delete']

#Nomes das features categoricas - comum a todos os datasets

#numeric_transformer = StandardScaler() ## removing the mean and scaling to unit variance.
numeric_transformer = MinMaxScaler() ## Varia de 0 a 1
#numeric_transformer = SimpleImputer()

hour_categories = np.arange(0, 24)
dow_categories  = np.arange(0, 7)
user_categories = df_lhud_1hora4m.user.unique()

#categorical_features = ['user','hour', 'dow']
categorical_features = ['hour', 'dow']
categorical_transformer = OneHotEncoder(
#    categories = [user_categories, hour_categories, dow_categories]
    categories = [hour_categories, dow_categories]
)

user_feature = ['user']
user_transformer = OrdinalEncoder(categories = [user_categories])
user_transformer_wd = OneHotEncoder(categories = [user_categories])

lhud_preprocessor = ColumnTransformer(
    transformers=[
        ('lhud_num', numeric_transformer, lhud_numeric_features),
        ('lhud_cat', categorical_transformer, categorical_features),
        ('lhud_user', user_transformer_wd, user_feature), #### ALTERADO PARA TESTAR ONEHOTENCODER ("_wd")
    ])

lhud_preprocessor_deep = ColumnTransformer(
    transformers=[
        ('lhud_num', numeric_transformer, lhud_numeric_features),
    ])

lhud_preprocessor_wide = ColumnTransformer(
    transformers=[
        ('lhud_cat', categorical_transformer, categorical_features),
        ('lhud_user_wd', user_transformer_wd, user_feature),
    ])

#Transformaçoes simples, com dados todos juntos
columns = lhud_numeric_features + categorical_features + user_feature
trans_lhud_4m    = lhud_preprocessor.fit_transform(df_lhud_1hora4m[columns])
trans_lhud_test  = lhud_preprocessor.transform(df_lhud_1hora_test[columns])
trans_lhud       = lhud_preprocessor.transform(df_lhud_1hora[columns])
trans_lhud_4m_13 = trans_lhud_4m[:,:13].toarray()
trans_lhud_test_13 =   trans_lhud_test[:,:13].toarray()

#Transformaçoes deep
columns_deep = lhud_numeric_features# + categorical_features + user_feature
trans_lhud_4m_deep    = lhud_preprocessor_deep.fit_transform(df_lhud_1hora4m[columns_deep])
trans_lhud_test_deep       = lhud_preprocessor_deep.transform(df_lhud_1hora_test[columns_deep])

#Transformaçoes wide
columns_wide = categorical_features + user_feature
trans_lhud_4m_wide    = lhud_preprocessor_wide.fit_transform(df_lhud_1hora4m[columns_wide])
trans_lhud_test_wide       = lhud_preprocessor_wide.transform(df_lhud_1hora_test[columns_wide])

# %%
type(trans_lhud_4m), trans_lhud_test_13.shape, trans_lhud_4m_13.shape
# Out:
# (scipy.sparse.csr.csr_matrix, (3278931, 13), (3294562, 13))

# %%
### Carrega do arquivos e dados do insider1

### Carrega do arquivo
acm2278_test = pd.read_pickle("acm2278_test.pkl")

### Carrega do arquivo
acm2278_test_full = pd.read_pickle("acm2278_test_full.pkl")

user = 'ACM2278'


### Carrega Labels preditos do Snorkel *** Ajustados
labels_pd = pd.read_hdf("labels_pd.hdf",'df')
labels_pd['anom'] = np.where((labels_pd[0]== 1),-1,1)
labels_pd[labels_pd['anom'] == -1].shape, labels_pd[labels_pd['anom'] == 1].shape

### Carrega Labels preditos do Snorkel *** General
labels_g_pd = pd.read_hdf("labels_g_pd.hdf",'df')
labels_g_pd['anom'] = np.where((labels_g_pd[0]== 1),-1,1)
labels_g_pd[labels_g_pd['anom'] == -1].shape, labels_g_pd[labels_g_pd['anom'] == 1].shape
# Out:
# ((6229, 2), (3272702, 2))

# %%
### Menos eficiente
# PAra não RNN com entradas 4044
ds = tf.data.Dataset.from_tensor_slices(trans_lhud[0:test_index])

ds = ds.map(lambda x: tf.concat(
            [tf.cast(x[:-1],tf.float32),
             tf.one_hot(tf.cast(x[-1],tf.int32),depth=4000)]
            ,-1),num_parallel_calls=tf.data.AUTOTUNE).map(lambda windows: 
            (windows, windows[:13]),
            num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds.take(train_index).batch(1024).cache().prefetch(1)
ds_test = ds.skip(train_index).batch(1024).cache().prefetch(1)

# %%
ds_train.element_spec
# Out:
# (TensorSpec(shape=(None, 4044), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 13), dtype=tf.float32, name=None))

# %%
######## - inicio SPARSE

# %%
##USANDO SPARSE - Mais Eficiente
# PAra não RNN com entradas 4044

ds_train = tf.data.Dataset.from_tensor_slices(convert_sparse_matrix_to_sparse_tensor(trans_lhud_4m))
output_train = tf.data.Dataset.from_tensor_slices(trans_lhud_4m_13)
ds_train = tf.data.Dataset.zip(({"input": ds_train}, {'output': output_train}))

ds_test = tf.data.Dataset.from_tensor_slices(convert_sparse_matrix_to_sparse_tensor(trans_lhud_test))
output_test = tf.data.Dataset.from_tensor_slices(trans_lhud_test_13)
ds_test = tf.data.Dataset.zip(({"input": ds_test}, {'output': output_test}))

ds_train = ds_train.batch(1024).cache().prefetch(4)
ds_test = ds_test.batch(1024).cache().prefetch(4)

ds_train.element_spec, ds_test.element_spec
# Out:
# (({'input': SparseTensorSpec(TensorShape([None, 4044]), tf.float64)},
#   {'output': TensorSpec(shape=(None, 13), dtype=tf.float64, name=None)}),
#  ({'input': SparseTensorSpec(TensorShape([None, 4044]), tf.float64)},
#   {'output': TensorSpec(shape=(None, 13), dtype=tf.float64, name=None)}))

# %%
##### - fim SPARSE

# %%
scores_df = pd.DataFrame(columns=["Model","Params","Accuracy","Precision","Recall","F1-Score","ROC-AUC", "CM"])
index=0
scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Model      0 non-null      object
#  1   Params     0 non-null      object
#  2   Accuracy   0 non-null      object
#  3   Precision  0 non-null      object
#  4   Recall     0 non-null      object
#  5   F1-Score   0 non-null      object
#  6   ROC-AUC    0 non-null      object
#  7   CM         0 non-null      object
# dtypes: object(8)
# memory usage: 0.0+ bytes

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
def objective(space):
    
    keras.backend.clear_session()
    
    input_feat = keras.layers.Input(shape=[4044], name="input", sparse=True, dtype=tf.float64)
            
    sae = keras.models.Sequential([

        #keras.layers.BatchNormalization(),
    
        keras.layers.Dense(space['first'], 
                                  kernel_initializer=space['kernel_init']),
        
        keras.layers.BatchNormalization(),
        keras.layers.Activation(space['activ']),
        
        keras.layers.ActivityRegularization(space['l1_reg']),

        keras.layers.Dense(space['second'], 
                                  kernel_initializer=space['kernel_init']),
        
        keras.layers.BatchNormalization(),
        keras.layers.Activation(space['activ']),
    
        keras.layers.Dense(space['middle'], 
                                  kernel_initializer=space['kernel_init']),
        
        keras.layers.BatchNormalization(),
        keras.layers.Activation(space['activ']),
    
        keras.layers.Dense(space['second'], 
                                  kernel_initializer=space['kernel_init']),
    
        keras.layers.BatchNormalization(),
        keras.layers.Activation(space['activ']),
    
        keras.layers.Dense(space['first'], 
                                  kernel_initializer=space['kernel_init']),
        
        keras.layers.BatchNormalization(),
        keras.layers.Activation(space['activ']),
    
    ])
    
    sae = sae(input_feat)
    
    output = keras.layers.Dense(13, name="output")(sae)
    
    model = keras.models.Model(inputs=[input_feat], outputs=[output])
        
    model.compile(loss=space['loss_ob'], optimizer=space['optimizer'], metrics=space['metrics'])

    history = model.fit(ds_train, epochs=space['epochs'], verbose=0)
    
    y_pred = model.predict(ds_test)
    
    anomalyScores, den_thres = dnn_tf_anomScores(
    y_pred, trans_lhud_test_13, df_lhud_1hora_test, 98.0)
    
    a,p,r,f,cm,auc_sc = benchmark_snorkel(labels_g_pd,anomalyScores)
    
    global index
    scores_df.loc[index,:]=np.array([index,space,a,p,r,f,auc_sc,np.reshape(cm,(4))],dtype=object)
    
    index=index+1
    
    print(space,r)
    
    return {'loss': -r, 'status': STATUS_OK, 'space': space,
            'model': model, 'f1_score': f,'auc_sc': auc_sc,
           'precision': p, 'recall': r, 'c_matrix': cm}


space ={'first': hp.choice("first", np.arange(250, 500, 20)),
        'second': hp.choice('second', np.arange(50, 300, 25)),
        'middle': hp.choice('middle', np.arange(20, 60, 10)),
        'kernel_init' : hp.choice('kernel_init', ["he_normal"]),
        'activ' : hp.choice('activ', ["elu"]),
        #'dropout' : hp.choice('dropout', [0.0, 0.05, 0.1, 0.15, 0.2]),
        'loss_ob' : hp.choice('loss_ob', ["mae"]),
        'optimizer' : hp.choice('optimizer', ["nadam"]),
        'metrics' : hp.choice('metrics', ["mean_squared_error"]),
        'epochs' : hp.choice('epochs', [10]),
        'l1_reg' : hp.choice('l1_reg', [0.00001, 0.00005, 0.0001,0.0005,0.001,0.005,0.01])
    }

# %%
## Usando ActivityRegularization - testando possíveis valores
## Usando formato que funcionou com SPARSE!
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=30,
            trials=trials)
# Out:
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 100}
# 0.6436025044148338
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'l1_reg': 0.001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 175}
# 0.6341306790817146
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'l1_reg': 5e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 125}
# 0.4835447102263606
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 0.01, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 225}
# 0.604270348370525
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'l1_reg': 5e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 225}
# 0.615187028415476
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'l1_reg': 0.001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 250}
# 0.5179001444854712
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 5e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 225}
# 0.6195215925509713
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 275}
# 0.6200032107882485
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 0.0001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 100}
# 0.6678439556911222
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.6843795151709745
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'l1_reg': 5e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 275}
# 0.4146733022957136
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 250}
# 0.6336490608444373
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.6092470701557232
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'l1_reg': 1e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 125}
# 0.6187188954888425
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'l1_reg': 0.001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.40552255578744584
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.6776368598490929
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.47503612136779577
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 125}
# 0.4239845882164071
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'l1_reg': 0.0001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 225}
# 0.6373414673302296
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'l1_reg': 0.01, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 150}
# 0.6585326697704287
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.6339701396692888
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 50}
# 0.5835607641676032
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'l1_reg': 1e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 200}
# 0.5484026328463638
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 75}
# 0.6755498474875582
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.6142237919409215
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 275}
# 0.6291539572965162
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'l1_reg': 0.0001, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.5917482742013164
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 75}
# 0.5193449991973029
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.01, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 50}
# 0.38529458982180126
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'l1_reg': 1e-05, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 200}
# 0.6423181891154278
# 100%|████████████████████████████████████████████| 30/30 [2:16:56<00:00, 273.89s/trial, best loss: -0.6843795151709745]

# %%
#scores_df.sort_values(['ROC-AUC'], ascending=[False])#.loc[:,('Params','Recall','ROC-AUC')]
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#    Model                                             Params  Accuracy  \
# 19    19  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980701
# 25    25  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980675
# 7      7  {'activ': 'elu', 'epochs': 10, 'first': 390, '...  0.980674
# 33    33  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980667
# 6      6  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980655
# 18    18  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980638
# 8      8  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.980614
# 29    29  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.980602
# 10    10  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980545
# 39    39  {'activ': 'elu', 'epochs': 10, 'first': 390, '...  0.980541
# 28    28  {'activ': 'elu', 'epochs': 10, 'first': 450, '...  0.980522
# 11    11  {'activ': 'elu', 'epochs': 10, 'first': 270, '...   0.98051
# 30    30  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980509
# 21    21  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980508
# 3      3  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980506
# 35    35  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980491
# 17    17  {'activ': 'elu', 'epochs': 10, 'first': 270, '...  0.980456
# 16    16  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980454
# 23    23  {'activ': 'elu', 'epochs': 10, 'first': 310, '...  0.980451
# 0      0  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980449
# 14    14  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980438
# 34    34  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.980434
# 22    22  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980415
# 13    13  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980396
# 2      2  {'activ': 'elu', 'epochs': 10, 'first': 330, '...  0.980361
# 5      5  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.980359
# 36    36  {'activ': 'elu', 'epochs': 10, 'first': 330, '...  0.980348
# 31    31  {'activ': 'elu', 'epochs': 10, 'first': 390, '...  0.980317
# 9      9  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980301
# 4      4  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.980194
# 32    32  {'activ': 'elu', 'epochs': 10, 'first': 430, '...  0.980185
# 37    37  {'activ': 'elu', 'epochs': 10, 'first': 450, '...  0.980073
# 15    15  {'activ': 'elu', 'epochs': 10, 'first': 350, '...  0.980068
# 1      1  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.979969
# 12    12  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.979937
# 26    26  {'activ': 'elu', 'epochs': 10, 'first': 250, '...  0.979905
# 27    27  {'activ': 'elu', 'epochs': 10, 'first': 250, '...  0.979711
# 20    20  {'activ': 'elu', 'epochs': 10, 'first': 350, '...  0.979676
# 24    24  {'activ': 'elu', 'epochs': 10, 'first': 330, '...  0.979641
# 38    38  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.979564
#
#    Precision    Recall  F1-Score   ROC-AUC                            CM
# 19  0.065007   0.68438  0.118735  0.901565  [3211387, 61315, 1966, 4263]
# 25  0.064365  0.677637  0.117564  0.840294  [3211344, 61358, 2008, 4221]
# 7   0.064335  0.677316  0.117508  0.850816  [3211342, 61360, 2010, 4219]
# 33  0.064167   0.67555  0.117201  0.887542  [3211331, 61371, 2021, 4208]
# 6   0.063862  0.672339  0.116644  0.898767  [3211311, 61391, 2041, 4188]
# 18  0.063435  0.667844  0.115865  0.915037  [3211283, 61419, 2069, 4160]
# 8    0.06284  0.661583  0.114778  0.907809  [3211244, 61458, 2108, 4121]
# 29  0.062551  0.658533  0.114249  0.864082  [3211225, 61477, 2127, 4102]
# 10  0.061132  0.643603  0.111659  0.925715  [3211132, 61570, 2220, 4009]
# 39   0.06101  0.642318  0.111436  0.895504  [3211124, 61578, 2228, 4001]
# 28  0.060538  0.637341  0.110573  0.892763  [3211093, 61609, 2259, 3970]
# 11  0.060233  0.634131  0.110016  0.857019  [3211073, 61629, 2279, 3950]
# 30  0.060217   0.63397  0.109988  0.806436  [3211072, 61630, 2280, 3949]
# 21  0.060187  0.633649  0.109932  0.854213  [3211070, 61632, 2282, 3947]
# 3   0.060156  0.633328  0.109876  0.838358  [3211068, 61634, 2284, 3945]
# 35   0.05976  0.629154  0.109152  0.898506  [3211042, 61660, 2310, 3919]
# 17  0.058891  0.620003  0.107565  0.901616  [3210985, 61717, 2367, 3862]
# 16  0.058845  0.619522  0.107481  0.908093  [3210982, 61720, 2370, 3859]
# 23  0.058769  0.618719  0.107342  0.876125  [3210977, 61725, 2375, 3854]
# 0   0.058723  0.618237  0.107258  0.902904  [3210974, 61728, 2378, 3851]
# 14  0.058433  0.615187  0.106729  0.832108  [3210955, 61747, 2397, 3832]
# 34  0.058342  0.614224  0.106562  0.841798  [3210949, 61753, 2403, 3826]
# 22  0.057869  0.609247  0.105699  0.897169  [3210918, 61784, 2434, 3795]
# 13  0.057396   0.60427  0.104835  0.814941  [3210887, 61815, 2465, 3764]
# 2   0.056527   0.59512  0.103248  0.797498  [3210830, 61872, 2522, 3707]
# 5   0.056466  0.594477  0.103136  0.836853  [3210826, 61876, 2526, 3703]
# 36  0.056207  0.591748  0.102663  0.899318  [3210809, 61893, 2543, 3686]
# 31  0.055429  0.583561  0.101242  0.926257  [3210758, 61944, 2594, 3635]
# 9   0.055003  0.579066  0.100464   0.82157  [3210731, 61971, 2622, 3607]
# 4   0.052349  0.551132  0.095616   0.87364  [3210556, 62146, 2796, 3433]
# 32  0.052092  0.548403  0.095147  0.907895  [3210542, 62160, 2813, 3416]
# 37   0.04933  0.519345  0.090101   0.84412  [3210358, 62344, 2994, 3235]
# 15  0.049193    0.5179  0.089851  0.899956  [3210349, 62353, 3003, 3226]
# 1   0.046723  0.491893   0.08534  0.796113  [3210188, 62514, 3165, 3064]
# 12  0.045929  0.483545   0.08389  0.809782  [3210135, 62567, 3217, 3012]
# 26  0.045121  0.475036  0.082414  0.923791  [3210082, 62620, 3270, 2959]
# 27  0.040273  0.423985  0.073558     0.848  [3209765, 62937, 3588, 2641]
# 20  0.039388  0.414673  0.071943   0.84749  [3209707, 62995, 3646, 2583]
# 24  0.038518  0.405523  0.070354  0.835701  [3209649, 63053, 3703, 2526]
# 38  0.036597  0.385295  0.066845  0.788432  [3209523, 63179, 3829, 2400]

# %%
#19	19	{'activ': 'elu', 'epochs': 10, 'first': 370, '...	0.980701	0.065007	0.68438	0.118735	0.901565	[3211387, 61315, 1966, 4263]
#{'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'l1_reg': 0.0005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
#0.6843795151709745
model = trials.results[9]['model'] ## NÃO REINICIOU A CONTAGEM DO SCORES_DF
model.save('best_bench_SAEBN_Snorkel3-068438.h5')

# %%
#10	10	{'activ': 'elu', 'epochs': 10, 'first': 410, '...	0.980545	0.061132	0.643603	0.111659	0.925715	[3211132, 61570, 2220, 4009]
#{'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'l1_reg': 0.005, 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 100}
#0.6436025044148338
## ROC-AUC 92%
model = trials.results[0]['model']  ## NÃO REINICIOU A CONTAGEM DO SCORES_DF
model.save('best_bench_SAEBN_Snorkel4-0643REC.h5')

# %%
## Usando ActivityRegularization - Atingiu 67%
## Usando formato que funcionou com SPARSE!
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=10,
            trials=trials)
# Out:
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 100}
# 0.6182372772515653
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 150}
# 0.4918927596724996
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 275}
# 0.5951196018622572
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 225}
# 0.6333279820195858
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 250}
# 0.5511318028576015
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 100}
# 0.5944774442125542
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 175}
# 0.6723390592390431
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 275}
# 0.6773157810242415
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 150}
# 0.6615829186065179
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 275}
# 0.5790656606196821
# 100%|██████████████████████████████████████████████| 10/10 [49:13<00:00, 295.34s/trial, best loss: -0.6773157810242415]

# %%
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#   Model                                             Params  Accuracy  \
# 7     7  {'activ': 'elu', 'epochs': 10, 'first': 390, '...  0.980674
# 6     6  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980655
# 8     8  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.980614
# 3     3  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980506
# 0     0  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980449
# 2     2  {'activ': 'elu', 'epochs': 10, 'first': 330, '...  0.980361
# 5     5  {'activ': 'elu', 'epochs': 10, 'first': 290, '...  0.980359
# 9     9  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.980301
# 4     4  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.980194
# 1     1  {'activ': 'elu', 'epochs': 10, 'first': 410, '...  0.979969
#
#   Precision    Recall  F1-Score   ROC-AUC                            CM
# 7  0.064335  0.677316  0.117508  0.850816  [3211342, 61360, 2010, 4219]
# 6  0.063862  0.672339  0.116644  0.898767  [3211311, 61391, 2041, 4188]
# 8   0.06284  0.661583  0.114778  0.907809  [3211244, 61458, 2108, 4121]
# 3  0.060156  0.633328  0.109876  0.838358  [3211068, 61634, 2284, 3945]
# 0  0.058723  0.618237  0.107258  0.902904  [3210974, 61728, 2378, 3851]
# 2  0.056527   0.59512  0.103248  0.797498  [3210830, 61872, 2522, 3707]
# 5  0.056466  0.594477  0.103136  0.836853  [3210826, 61876, 2526, 3703]
# 9  0.055003  0.579066  0.100464   0.82157  [3210731, 61971, 2622, 3607]
# 4  0.052349  0.551132  0.095616   0.87364  [3210556, 62146, 2796, 3433]
# 1  0.046723  0.491893   0.08534  0.796113  [3210188, 62514, 3165, 3064]

# %%
#{'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 275}
#0.6773157810242415
#7	7	{'activ': 'elu', 'epochs': 10, 'first': 390, '...	0.980674	0.064335	0.677316	0.117508	0.850816	[3211342, 61360, 2010, 4219]
model = trials.results[7]['model']
model.save('best_bench_SAEBN_Snorkel1-06773.h5')

# %%
#{'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 175}
#0.6723390592390431
#6	6	{'activ': 'elu', 'epochs': 10, 'first': 470, '...	0.980655	0.063862	0.672339	0.116644	0.898767	[3211311, 61391, 2041, 4188]
model = trials.results[6]['model']
model.save('best_bench_SAEBN_Snorkel2-06723.h5')

# %%
#8	8	{'activ': 'elu', 'epochs': 10, 'first': 290, '...	0.980614	0.06284	0.661583	0.114778	0.907809	[3211244, 61458, 2108, 4121]
#{'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': <keras.optimizer_v2.nadam.Nadam object at 0x0000023DFCC57C10>, 'second': 150}
#0.6615829186065179
model = trials.results[8]['model']
model.save('best_bench_SAEBN_Snorkel3-06615.h5')

# %%
model = trials.results[8]['model']
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 4044)]            0
# _________________________________________________________________
# sequential (Sequential)      (None, 290)               1279410
# _________________________________________________________________
# output (Dense)               (None, 13)                3783
# =================================================================
# Total params: 1,283,193
# Trainable params: 1,281,333
# Non-trainable params: 1,860
# _________________________________________________________________

# %%
## Usando formato que funcionou (hot encoder no tf) - Aqui não usa SPARSE!
## Atingiu 66,8%
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=100,
            trials=trials)
# Out:
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.44148338417081395
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 50}
# 0.5639749558516616
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 75}
# 0.5999357842350297
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 275}
# 0.6233745384491893
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 200}
# 0.5548242093433938
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 100}
# 0.5270508909937389
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 225}
# 0.5922298924385937
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.6688071921656766
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 250}
# 0.3902713116069995
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 250}
# 0.5249638786322042
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.6323647455450313
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.624177235511318
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 50}
# 0.5490447904960668
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 100}
# 0.5821159094557714
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 150}
# 0.5406967410499277
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.5832396853427516
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 100}
# 0.5554663669930968
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 125}
# 0.5721624658853749
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 100}
# 0.5819553700433456
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 150}
# 0.5264087333440359
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5649381923262161
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.6169529619521592
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5577139187670573
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.601701717771713
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5676673623374539
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 200}
# 0.6261037084604271
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 125}
# 0.6126183978166639
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 75}
# 0.6330069031947343
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 75}
# 0.61390271311607
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 75}
# 0.6419971102905764
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 75}
# 0.541178359287205
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.6646331674426071
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.6368598490929523
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.465885374859528
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 175}
# 0.5761759511960186
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 225}
# 0.6192005137261197
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 275}
# 0.5994541659977525
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 50}
# 0.562369561727404
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.620966447262803
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 225}
# 0.5968855353989404
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 125}
# 0.5665435864504736
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 250}
# 0.538609728688393
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 50}
# 0.623535077861615
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 150}
# 0.611976240166961
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.3843313533472468
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 275}
# 0.09166800449510355
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.6301171937710708
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 225}
# 0.6460105956012201
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 100}
# 0.60105956012201
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 250}
# 0.5126023438754214
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 150}
# 0.11013003692406485
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.6389468614544871
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 50}
# 0.6156686466527532
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5792262000321079
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 125}
# 0.6236956172740408
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.6521110932733987
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 200}
# 0.5614063252528496
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 100}
# 0.5464761598972547
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.5641354952640873
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 250}
# 0.609407609568149
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 200}
# 0.5588376946540375
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 150}
# 0.5695938352865628
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 225}
# 0.5005618879434901
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.5870926312409697
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 75}
# 0.5935142077379997
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.4779258307914593
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.5981698506983465
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 200}
# 0.5382886498635415
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.48498956493819234
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.5458340022475517
# {'activ': 'elu', 'epochs': 10, 'first': 470, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 275}
# 0.5923904318510195
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 125}
# 0.6472949109006261
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 50}
# 0.6346122973189918
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 275}
# 0.5761759511960186
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 50, 'optimizer': 'nadam', 'second': 100}
# 0.5755337935463156
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.5782629635575534
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5426232139990368
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.6609407609568149
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.5076256220902231
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.6167924225397335
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.6450473591266656
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.6061968213196339
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 250}
# 0.52512441804463
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 75}
# 0.6509873173864184
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.4398779900465564
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 225}
# 0.5822764488681972
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 150}
# 0.6431208861775566
# {'activ': 'elu', 'epochs': 10, 'first': 270, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 125}
# 0.5964039171616632
# {'activ': 'elu', 'epochs': 10, 'first': 330, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.4873976561245786
# {'activ': 'elu', 'epochs': 10, 'first': 410, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 50}
# 0.6052335848450795
# {'activ': 'elu', 'epochs': 10, 'first': 430, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 250}
# 0.459463798362498
# {'activ': 'elu', 'epochs': 10, 'first': 350, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 175}
# 0.6008990207095842
# {'activ': 'elu', 'epochs': 10, 'first': 250, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
# 0.5896612618397816
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 100}
# 0.6244983143361695
# {'activ': 'elu', 'epochs': 10, 'first': 390, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 75}
# 0.5732862417723551
# {'activ': 'elu', 'epochs': 10, 'first': 490, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 175}
# 0.5851661582918607
# {'activ': 'elu', 'epochs': 10, 'first': 450, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 40, 'optimizer': 'nadam', 'second': 150}
# 0.6020227965965644
# {'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 225}
# 0.6206453684379515
# {'activ': 'elu', 'epochs': 10, 'first': 290, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 250}
# 0.52512441804463
# {'activ': 'elu', 'epochs': 10, 'first': 310, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 20, 'optimizer': 'nadam', 'second': 200}
# 0.54438914753572
# 100%|██████████████████████████████████████████| 100/100 [8:07:31<00:00, 292.51s/trial, best loss: -0.6688071921656766]

# %%
scores_df.sort_values(['Recall','ROC-AUC'], ascending=[False,False])#.loc[:,('Params','Recall','ROC-AUC')]
# Out:
#    Model                                             Params  Accuracy  \
# 7      7  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980641
# 31    31  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.980625
# 77    77  {'activ': 'elu', 'epochs': 10, 'first': 450, '...  0.980611
# 55    55  {'activ': 'elu', 'epochs': 10, 'first': 470, '...  0.980578
# 83    83  {'activ': 'elu', 'epochs': 10, 'first': 370, '...  0.980574
# ..   ...                                                ...       ...
# 84    84  {'activ': 'elu', 'epochs': 10, 'first': 450, '...  0.979771
# 8      8  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.979583
# 44    44  {'activ': 'elu', 'epochs': 10, 'first': 310, '...   0.97956
# 50    50  {'activ': 'elu', 'epochs': 10, 'first': 350, '...  0.978519
# 45    45  {'activ': 'elu', 'epochs': 10, 'first': 490, '...  0.978448
#
#    Precision    Recall  F1-Score   ROC-AUC                            CM
# 7   0.063526  0.668807  0.116032  0.902545  [3211289, 61413, 2063, 4166]
# 31   0.06313  0.664633  0.115307  0.905458  [3211263, 61439, 2089, 4140]
# 77  0.062779  0.660941  0.114667  0.846139  [3211240, 61462, 2112, 4117]
# 55  0.061941  0.652111  0.113135  0.894649  [3211185, 61517, 2167, 4062]
# 83  0.061834  0.650987   0.11294  0.893987  [3211178, 61524, 2174, 4055]
# ..       ...       ...       ...       ...                           ...
# 84  0.041782  0.439878  0.076315  0.888392  [3209863, 62839, 3489, 2740]
# 8    0.03707  0.390271  0.067708  0.872021  [3209554, 63148, 3798, 2431]
# 44  0.036506  0.384331  0.066678  0.848122  [3209517, 63185, 3835, 2394]
# 50  0.010461   0.11013  0.019107  0.787696   [3207809, 64893, 5543, 686]
# 45  0.008707  0.091668  0.015903  0.769121   [3207693, 65009, 5658, 571]
#
# [100 rows x 8 columns]

# %%
trials.results[7]['space']
# Out:
# {'activ': 'elu',
#  'epochs': 10,
#  'first': 370,
#  'kernel_init': 'he_normal',
#  'loss_ob': 'mae',
#  'metrics': 'mean_squared_error',
#  'middle': 30,
#  'optimizer': 'nadam',
#  'second': 200}

# %%
scores_df.iloc[7]
# Out:
# Model                                                        7
# Params       {'activ': 'elu', 'epochs': 10, 'first': 370, '...
# Accuracy                                              0.980641
# Precision                                             0.063526
# Recall                                                0.668807
# F1-Score                                              0.116032
# ROC-AUC                                               0.902545
# CM                                [3211289, 61413, 2063, 4166]
# Name: 7, dtype: object

# %%
#{'activ': 'elu', 'epochs': 10, 'first': 370, 'kernel_init': 'he_normal', 'loss_ob': 'mae', 'metrics': 'mean_squared_error', 'middle': 30, 'optimizer': 'nadam', 'second': 200}
#0.6688071921656766
#7	{'activ': 'elu', 'epochs': 10, 'first': 370, '...	0.980641	0.063526	0.668807	0.116032	0.902545	[3211289, 61413, 2063, 4166]
model = trials.results[7]['model']
model.save('best_bench_SAEBN_Snorkel.h5')
